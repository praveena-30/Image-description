# %%
import tensorflow as tf
import keras
import sys, time, os, warnings 
import numpy as np
import pandas as pd 
from collections import Counter
warnings.filterwarnings("ignore")
print("python {}".format(sys.version))
print("keras version {}".format(keras.__version__)); del keras
print("tensorflow version {}".format(tf.__version__))

# Configuring gpu for notebook
config = tf.compat.v1.ConfigProto()
config.gpu_options.per_process_gpu_memory_fraction = 0.95
config.gpu_options.visible_device_list = "0"
tf.compat.v1.keras.backend.set_session(tf.compat.v1.Session(config=config))


def set_seed(sd=123):
    from numpy.random import seed
    from tensorflow import set_random_seed
    import random as rn
    ## numpy random seed
    seed(sd)
    ## core python's random number 
    rn.seed(sd)
    ## tensor flow's random number
    set_random_seed(sd)
# Out:
# python 3.12.4 (tags/v3.12.4:8e8a4ba, Jun  6 2024, 19:30:16) [MSC v.1940 64 bit (AMD64)]
# keras version 3.4.1
# tensorflow version 2.17.0
# WARNING:tensorflow:From C:\Users\User\AppData\Local\Temp\ipykernel_9428\4234366435.py:13: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 16
#      14 config.gpu_options.per_process_gpu_memory_fraction = 0.95
#      15 config.gpu_options.visible_device_list = "0"
# ---> 16 tf.compat.v1.keras.backend.set_session(tf.compat.v1.Session(config=config))
#      19 def set_seed(sd=123):
#      20     from numpy.random import seed
#
# AttributeError: module 'keras._tf_keras.keras.backend' has no attribute 'set_session'

# %%
## The location of the Flickr8K_ photos
dir_Flickr_jpg = "C:/ss/image_caption/Flickr8k_Dataset/Flicker8k_Dataset"
## The location of the caption file
dir_Flickr_text = "C:/ss/image_caption/Flickr8k_text/Flickr8k.token.txt"

jpgs = os.listdir(dir_Flickr_jpg)
print("The number of jpg flies in Flicker8k: {}".format(len(jpgs)))
# Out:
# The number of jpg flies in Flicker8k: 8094

# %%
## read in the Flickr caption data
file = open(dir_Flickr_text,'r')
text = file.read()
file.close()


datatxt = []
for line in text.split('\n'):
    col = line.split('\t')
    if len(col) == 1:
        continue
    w = col[0].split("#")
    datatxt.append(w + [col[1].lower()])

df_txt = pd.DataFrame(datatxt,columns=["filename","index","caption"])


uni_filenames = np.unique(df_txt.filename.values)
print("The number of unique file names : {}".format(len(uni_filenames)))
print("The distribution of the number of captions for each image:")

# Counting number of captions for each image using counter
Counter(Counter(df_txt.filename.values).values())
# Out:
# The number of unique file names : 8092
# The distribution of the number of captions for each image:
# Counter({5: 8092})

# %%
df_txt[:6]
# Out:
#                     filename index  \
# 0  1000268201_693b08cb0e.jpg     0
# 1  1000268201_693b08cb0e.jpg     1
# 2  1000268201_693b08cb0e.jpg     2
# 3  1000268201_693b08cb0e.jpg     3
# 4  1000268201_693b08cb0e.jpg     4
# 5  1001773457_577c3a7d70.jpg     0
#
#                                              caption
# 0  a child in a pink dress is climbing up a set o...
# 1              a girl going into a wooden building .
# 2   a little girl climbing into a wooden playhouse .
# 3  a little girl climbing the stairs to her playh...
# 4  a little girl in a pink dress going into a woo...
# 5         a black dog and a spotted dog are fighting

# %%
from keras.preprocessing.image import load_img, img_to_array
import matplotlib.pyplot as plt

# Displaying (npic = 5) pics from the dataset
npic = 5
npix = 224
target_size = (npix,npix,3)

count = 1
fig = plt.figure(figsize=(10,20))
for jpgfnm in uni_filenames[:npic]:
    filename = dir_Flickr_jpg + '/' + jpgfnm
    captions = list(df_txt["caption"].loc[df_txt["filename"]==jpgfnm].values)
    image_load = load_img(filename, target_size=target_size)
    
    ax = fig.add_subplot(npic,2,count,xticks=[],yticks=[])
    ax.imshow(image_load)
    count += 1
    
    ax = fig.add_subplot(npic,2,count)
    plt.axis('off')
    ax.plot()
    ax.set_xlim(0,1)
    ax.set_ylim(0,len(captions))
    for i, caption in enumerate(captions):
        ax.text(0,i,caption,fontsize=20)
    count += 1
plt.show()

# %%
def df_word(df_txt):
    vocabulary = []
    for txt in df_txt.caption.values:
        vocabulary.extend(txt.split())
    print('Vocabulary Size: %d' % len(set(vocabulary)))
    ct = Counter(vocabulary)
    dfword = pd.DataFrame(list(ct.items()), columns=['word', 'count'])
    dfword.sort_values(by='count', ascending=False, inplace=True)
    dfword = dfword.reset_index()[["word","count"]]
    return(dfword)
dfword = df_word(df_txt)
dfword.head(3)
# Out:
# Vocabulary Size: 8918
#   word  count
# 0    a  62989
# 1    .  36581
# 2   in  18975

# %%
topn = 50

def plthist(dfsub, title="The top 50 most frequently appearing words"):
    plt.figure(figsize=(20,3))
    plt.bar(dfsub.index,dfsub["count"])
    plt.yticks(fontsize=20)
    plt.xticks(dfsub.index,dfsub["word"],rotation=90,fontsize=20)
    plt.title(title,fontsize=20)
    plt.show()

plthist(dfword.iloc[:topn,:],
        title="The top 50 most frequently appearing words")
plthist(dfword.iloc[-topn:,:],
        title="The least 50 most frequently appearing words")

# %%
import string
text_original = "I scored 21 in NLP, but Akshat topped. I have python v3.8. It's 4:20 pm. Could you give us 20 on 20?"

print(text_original)
print("\nRemove punctuations..")
def remove_punctuation(text_original):
    text_no_punctuation = text_original.translate(str.maketrans('','',string.punctuation))
    return(text_no_punctuation)
text_no_punctuation = remove_punctuation(text_original)
print(text_no_punctuation)


print("\nRemove a single character word..")
def remove_single_character(text):
    text_len_more_than1 = ""
    for word in text.split():
        if len(word) > 1:
            text_len_more_than1 += " " + word
    return(text_len_more_than1)
text_len_more_than1 = remove_single_character(text_no_punctuation)
print(text_len_more_than1)

print("\nRemove words with numeric values..")
def remove_numeric(text,printTF=False):
    text_no_numeric = ""
    for word in text.split():
        isalpha = word.isalpha()
        if printTF:
            print("    {:10} : {:}".format(word,isalpha))
        if isalpha:
            text_no_numeric += " " + word
    return(text_no_numeric)
text_no_numeric = remove_numeric(text_len_more_than1,printTF=True)
print(text_no_numeric)
# Out:
# I scored 21 in NLP, but Akshat topped. I have python v3.8. It's 4:20 pm. Could you give us 20 on 20?
#
# Remove punctuations..
# I scored 21 in NLP but Akshat topped I have python v38 Its 420 pm Could you give us 20 on 20
#
# Remove a single character word..
#  scored 21 in NLP but Akshat topped have python v38 Its 420 pm Could you give us 20 on 20
#
# Remove words with numeric values..
#     scored     : True
#     21         : False
#     in         : True
#     NLP        : True
#     but        : True
#     Akshat     : True
#     topped     : True
#     have       : True
#     python     : True
#     v38        : False
#     Its        : True
#     420        : False
#     pm         : True
#     Could      : True
#     you        : True
#     give       : True
#     us         : True
#     20         : False
#     on         : True
#     20         : False
#  scored in NLP but Akshat topped have python Its pm Could you give us on

# %%
def text_clean(text_original):
    text = remove_punctuation(text_original)
    text = remove_single_character(text)
    text = remove_numeric(text)
    return(text)


for i, caption in enumerate(df_txt.caption.values):
    newcaption = text_clean(caption)
    df_txt["caption"].iloc[i] = newcaption

# %%
dfword = df_word(df_txt)
plthist(dfword.iloc[:topn,:],
        title="The top 50 most frequently appearing words")
plthist(dfword.iloc[-topn:,:],
        title="The least 50 most frequently appearing words")
# Out:
# Vocabulary Size: 8763

# %%
from copy import copy
def add_start_end_seq_token(captions):
    caps = []
    for txt in captions:
        txt = 'startseq ' + txt + ' endseq'
        caps.append(txt)
    return(caps)
df_txt0 = copy(df_txt)
df_txt0["caption"] = add_start_end_seq_token(df_txt["caption"])
df_txt0.head(5)
del df_txt

# %%
modelvgg = tf.keras.applications.VGG16(include_top=True, weights=None)
## load the locally saved weights 
modelvgg.load_weights("C:/ss/image_caption/vgg16_weights_tf_dim_ordering_tf_kernels.h5")
modelvgg.summary()
# Out:
# Model: "vgg16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 224, 224, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv1 (Conv2D)                │ (None, 224, 224, 64)        │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv2 (Conv2D)                │ (None, 224, 224, 64)        │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_pool (MaxPooling2D)           │ (None, 112, 112, 64)        │               0 │
# ...

# %%
modelvgg.layers.pop()
modelvgg = tf.keras.Model(inputs=modelvgg.inputs, outputs=modelvgg.layers[-2].output)
## show the deep learning model
modelvgg.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 224, 224, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv1 (Conv2D)                │ (None, 224, 224, 64)        │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv2 (Conv2D)                │ (None, 224, 224, 64)        │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_pool (MaxPooling2D)           │ (None, 112, 112, 64)        │               0 │
# ...

# %%
from keras.preprocessing.image import load_img, img_to_array
from keras.applications.vgg16 import preprocess_input
from collections import OrderedDict

images = OrderedDict()
npix = 224
target_size = (npix,npix,3)
data = np.zeros((len(jpgs),npix,npix,3))
for i,name in enumerate(jpgs):
    # load an image from file
    filename = dir_Flickr_jpg + '/' + name
    image = load_img(filename, target_size=target_size)
    # convert the image pixels to a numpy array
    image = img_to_array(image)
    nimage = preprocess_input(image)
    
    y_pred = modelvgg.predict(nimage.reshape( (1,) + nimage.shape[:3]))
    images[name] = y_pred.flatten()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 820ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 325ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 273ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 264ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step
# ...

# %%
# Example list of images (similar to your 'images' variable)
images = [
    {'filename': '1000268201_693b08cb0e.jpg', 'data': 'some data 1'},
    {'filename': '1001773457_577c3a7d70.jpg', 'data': 'some data 2'},
    {'filename': '1002674143_1b742ab4b8.jpg', 'data': 'some data 3'}
]

# Define the filename you want to retrieve data for
filename_to_find = '1000268201_693b08cb0e.jpg'

# Iterate through the list to find the matching filename
found_data = None
for item in images:
    if item['filename'] == filename_to_find:
        found_data = item['data']
        break

# Print the found data
print(found_data)
# Out:
# some data 1

# %%
import os

# Step 1: Define the directory containing your images
dataset_dir = 'C:/ss/image_caption/Flickr8k_Dataset/Flicker8k_Dataset'

# Step 2: List all files in the directory (assuming all are images)
image_files = os.listdir(dataset_dir)

# Step 3: Filter only image files (if needed)
image_files = [file for file in image_files if file.endswith('.jpg') or file.endswith('.png')]

# Step 4: Calculate the number of images
num_images = len(image_files)

print("Number of images:", num_images)
# Out:
# Number of images: 8091

# %%
import pandas as pd

# Assuming datatxt structure with 3 columns: ["filename", "index", "caption"]
datatxt = [
    ["file1.jpg", 1, "caption1"],
    ["file2.jpg", 2, "caption2"],
    ["file3.jpg", 3, "caption3"],
    # More rows...
]

# Check the structure of datatxt
print(datatxt[:5])  # Print first 5 rows to inspect structure

# Create DataFrame from datatxt
df_txt0 = pd.DataFrame(datatxt, columns=["filename", "index", "caption"])

# Print DataFrame information to verify columns
print(df_txt0.info())
# Out:
# [['file1.jpg', 1, 'caption1'], ['file2.jpg', 2, 'caption2'], ['file3.jpg', 3, 'caption3']]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   filename  3 non-null      object
#  1   index     3 non-null      int64
#  2   caption   3 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 204.0+ bytes
# None

# %%
# Example list
dimages = [1, 2, 3, 4, 5]

# Check the number of elements in the list
num_elements = len(dimages)
print("Number of elements in dimages:", num_elements)
# Out:
# Number of elements in dimages: 5

# %%
dcaptions = ["caption1", "caption2", "caption3", "caption4", "caption5"]
print(dcaptions[:5])
# Out:
# ['caption1', 'caption2', 'caption3', 'caption4', 'caption5']

# %%
from tensorflow.keras.preprocessing.text import Tokenizer

## the maximum number of words in dictionary
nb_words = 8000
tokenizer = Tokenizer(nb_words=nb_words)
tokenizer.fit_on_texts(dcaptions)
vocab_size = len(tokenizer.word_index) + 1
print("vocabulary size : {}".format(vocab_size))
dtexts = tokenizer.texts_to_sequences(dcaptions)
# Out:
# vocabulary size : 6

# %%
dtexts[:5]
# Out:
# [[1], [2], [3], [4], [5]]

# %%
fnames = ["file1.jpg", "file2.jpg", "file3.jpg"]
fnm_test, fnm_val, fnm_train = split_test_val_train(fnames, Ntest, Nval)
def some_function():
    fnames = ["file1.jpg", "file2.jpg", "file3.jpg"]
    fnm_test, fnm_val, fnm_train = split_test_val_train(fnames, Ntest, Nval)

# Call the function to define and use fnames
some_function()
# Define fnames as a list of filenames
fnames = ["file1.jpg", "file2.jpg", "file3.jpg"]

# Use fnames in a function call
fnm_test, fnm_val, fnm_train = split_test_val_train(fnames, Ntest, Nval)

# %%
maxlen = np.max([len(text) for text in dtexts])

# %%
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical

def preprocessing(dtexts,dimages):
    N = len(dtexts)
    print("# captions/images = {}".format(N))

    assert(N==len(dimages))
    Xtext, Ximage, ytext = [],[],[]
    for text,image in zip(dtexts,dimages):

        for i in range(1,len(text)):
            in_text, out_text = text[:i], text[i]
            in_text = pad_sequences([in_text],maxlen=maxlen).flatten()
            out_text = to_categorical(out_text,num_classes = vocab_size)

            Xtext.append(in_text)
            Ximage.append(image)
            ytext.append(out_text)

    Xtext  = np.array(Xtext)
    Ximage = np.array(Ximage)
    ytext  = np.array(ytext)
    print(" {} {} {}".format(Xtext.shape,Ximage.shape,ytext.shape))
    return(Xtext,Ximage,ytext)


Xtext_train, Ximage_train, ytext_train = preprocessing(dt_train,di_train)
Xtext_val,   Ximage_val,   ytext_val   = preprocessing(dt_val,di_val)
# pre-processing is not necessary for testing data
#Xtext_test,  Ximage_test,  ytext_test  = preprocessing(dt_test,di_test)
# Out:
# # captions/images = 3
#  (0,) (0,) (0,)
# # captions/images = 1
#  (0,) (0,) (0,)

# %%
Xtext_train[:14]
# Out:
# array([], dtype=float64)

# %%
Ximage_train.shape
# Out:
# (0,)

# %%
ytext_train.shape
# Out:
# (0,)

# %%
# Print the shape of Ximage_train to diagnose the IndexError
print(Ximage_train.shape)
# Out:
# (0,)

# %%
input_image = layers.Input(shape=(Ximage_train.shape[0],))
print(Ximage_train.shape)  # Inspect the shape of Ximage_train
# Assuming Ximage_train is a 1D array or list
input_image = layers.Input(shape=(Ximage_train.shape[0],))
print(Ximage_train.shape)  # Inspect the shape of Ximage_train
# Out:
# (0,)
# (0,)

# %%
print("Ximage_train shape:", Ximage_train.shape)
print("Xtext_train shape:", Xtext_train.shape)
print("ytext_train shape:", ytext_train.shape)
if Ximage_train.shape[0] > 0:
    print(Ximage_train[0])
else:
    print("Ximage_train is empty or has no elements.")
# Out:
# Ximage_train shape: (0,)
# Xtext_train shape: (0,)
# ytext_train shape: (0,)
# Ximage_train is empty or has no elements.

# %%
from tensorflow.keras.layers import Input, Dense, LSTM, Embedding, concatenate

# Example values (customize as per your requirement)
vocab_size = 10000  # Example: Number of unique words in your vocabulary
embedding_dim = 100  # Example: Dimensionality of the embedding space

# Example model architecture (customize as per your requirement)
input_image = Input(shape=(image_features,))
input_text = Input(shape=(max_caption_length,))
image_dense = Dense(256, activation='relu')(input_image)
text_embedding = Embedding(vocab_size, embedding_dim)(input_text)
lstm = LSTM(256)(text_embedding)
combined = concatenate([image_dense, lstm])
output = Dense(vocab_size, activation='softmax')(combined)

model = Model(inputs=[input_image, input_text], outputs=output)

# Compile the model
model.compile(loss='categorical_crossentropy', optimizer='adam')

# Print model summary
model.summary()
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_22 (InputLayer)   │ (None, 20)                │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ input_layer_21 (InputLayer)   │ (None, 512)               │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ embedding (Embedding)         │ (None, 20, 100)           │       1,000,000 │ input_layer_22[0][0]       │
# ...

# %%
print(Ximage_train.shape,Xtext_train.shape,ytext_train.shape)
# Out:
# (0,) (0,) (0,)

# %%
# Assuming X_train_images, X_train_texts, X_val_images, X_val_texts are defined and preprocessed
# Train your model
hist = model.fit(
    x=[X_train_images, X_train_texts],
    y=y_train,
    epochs=10,
    validation_data=([X_val_images, X_val_texts], y_val)
)

# Plot training history if `hist` is defined
if 'hist' in locals():
    import matplotlib.pyplot as plt

    for metric in ['loss', 'val_loss']:
        plt.plot(hist.history[metric], label=metric)

    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()
else:
    print("Error: hist is not defined. Check model.fit() execution.")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[213], line 3
#       1 # Assuming X_train_images, X_train_texts, X_val_images, X_val_texts are defined and preprocessed
#       2 # Train your model
# ----> 3 hist = model.fit(
#       4     x=[X_train_images, X_train_texts],
#       5     y=y_train,
#       6     epochs=10,
#       7     validation_data=([X_val_images, X_val_texts], y_val)
#       8 )
#      10 # Plot training history if `hist` is defined
#      11 if 'hist' in locals():
#
# File D:\yashas gatty\Lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
# ...

# %%
index_word = dict([(index,word) for word, index in tokenizer.word_index.items()])
def predict_caption(image):
    '''
    image.shape = (1,4462)
    '''

    in_text = 'startseq'

    for iword in range(maxlen):
        sequence = tokenizer.texts_to_sequences([in_text])[0]
        sequence = pad_sequences([sequence],maxlen)
        yhat = model.predict([image,sequence],verbose=0)
        yhat = np.argmax(yhat)
        newword = index_word[yhat]
        in_text += " " + newword
        if newword == "endseq":
            break
    return(in_text)



npic = 5
npix = 224
target_size = (npix,npix,3)

count = 1
fig = plt.figure(figsize=(10,20))
for jpgfnm, image_feature in zip(fnm_test[:npic],di_test[:npic]):
    ## images 
    filename = dir_Flickr_jpg + '/' + jpgfnm
    image_load = load_img(filename, target_size=target_size)
    ax = fig.add_subplot(npic,2,count,xticks=[],yticks=[])
    ax.imshow(image_load)
    count += 1

    ## captions
    caption = predict_caption(image_feature.reshape(1,len(image_feature)))
    ax = fig.add_subplot(npic,2,count)
    plt.axis('off')
    ax.plot()
    ax.set_xlim(0,1)
    ax.set_ylim(0,1)
    ax.text(0,0.5,caption,fontsize=20)
    count += 1

plt.show()

# %%
# Example assuming 'images' is intended to be a dictionary of image paths
import cv2  # Example with OpenCV, adjust based on your preferred library

# Check the type of 'images' to confirm it's a dictionary
if isinstance(images, dict):
    image_path = images['1000268201_693b08cb0e.jpg']  # Replace with the key corresponding to the image path you want to inspect
    image_data = cv2.imread(image_path)
    if image_data is not None:
        image_shape = image_data.shape
        print(f"Shape of image '{image_path}': {image_shape}")
    else:
        print(f"Failed to load image from path '{image_path}'")
else:
    print("Error: 'images' is not a dictionary.")
# Out:
# Error: 'images' is not a dictionary.

# %%
# Example correction assuming 'image_feature' is an array or tensor
import numpy as np  # Import numpy for array operations (if not already imported)

# Ensure 'image_feature' is an array or tensor with the correct shape
if isinstance(image_feature, np.ndarray):
    if len(image_feature.shape) == 1:
        image_feature = image_feature.reshape(1, len(image_feature))  # Reshape to (1, len(image_feature))
    else:
        # Handle other cases or ensure 'image_feature' has the correct shape
        pass  # Optionally handle other shape scenarios
else:
    print("Error: 'image_feature' is not an ndarray.")

# Assuming 'predict_caption' expects a reshaped input, perform prediction
if isinstance(image_feature, np.ndarray):
    caption = predict_caption(image_feature)
    caption = caption.split()
    caption = caption[1:-1]  # Remove startreg and endreg tokens
    print("Predicted Caption:", caption)
else:
    print("Error: 'image_feature' is not an ndarray or could not be reshaped.")
# Out:
# Error: 'image_feature' is not an ndarray.
# Error: 'image_feature' is not an ndarray or could not be reshaped.

# %%
pred_good
# Out:
# []

# %%
pred_bad[:2]
# Out:
# []

# %%
print("Mean BLEU {:4.3f}".format(np.mean(bleus)))
# Out:
# Mean BLEU  nan

# %%
def plot_images(pred_bad):
    def create_str(caption_true):
        strue = ""
        for s in caption_true:
            strue += " " + s
        return(strue)
    npix = 224
    target_size = (npix,npix,3)    
    count = 1
    fig = plt.figure(figsize=(10,20))
    npic = len(pred_bad)
    for pb in pred_bad:
        bleu,jpgfnm,caption_true,caption = pb
        ## images 
        filename = dir_Flickr_jpg + '/' + jpgfnm
        image_load = load_img(filename, target_size=target_size)
        ax = fig.add_subplot(npic,2,count,xticks=[],yticks=[])
        ax.imshow(image_load)
        count += 1

        caption_true = create_str(caption_true)
        caption = create_str(caption)
        
        ax = fig.add_subplot(npic,2,count)
        plt.axis('off')
        ax.plot()
        ax.set_xlim(0,1)
        ax.set_ylim(0,1)
        ax.text(0,0.7,"true:" + caption_true,fontsize=20)
        ax.text(0,0.4,"pred:" + caption,fontsize=20)
        ax.text(0,0.1,"BLEU: {}".format(bleu),fontsize=20)
        count += 1
    plt.show()

print("Bad Caption")
plot_images(pred_bad)
print("Good Caption")
plot_images(pred_good)
# Out:
# Bad Caption
# Good Caption

# %%
# Out:
#   Cell In[231], line 2
#     OSError: [Errno 22] Unable to synchronously open file (unable to open file: name = 'C:\ss\image_caption
#                                                                                        ^
# SyntaxError: unterminated string literal (detected at line 2)

# %%
# Out:
# 'C:\\ss\\image_caption\\Flickr8k_Dataset\\Flicker8k_Dataset'

# %%
# Importing libraries

import tkinter as tk
from PIL import Image, ImageTk
from tkinter import filedialog

# %%
import os

os.chdir('C:\ss\image_caption')
os.getcwd()
# Out:
# 'C:\\ss\\image_caption'

# %%
def upload_img():
    global img, image_data
    for img_display in frame.winfo_children():
        img_display.destroy()

    image_data = filedialog.askopenfilename(initialdir="/", title="Choose an image",
                                       filetypes=(("all files", "*.*"), ("png files", "*.png")))
    basewidth = 300
    img = Image.open(image_data)
    wpercent = (basewidth / float(img.size[0]))
    hsize = int((float(img.size[1]) * float(wpercent)))
    img = img.resize((basewidth, hsize), Image.ANTIALIAS)
    img = ImageTk.PhotoImage(img)
    file_name = image_data.split('/')
    panel = tk.Label(frame, text= str(file_name[len(file_name)-1]).upper()).pack()
    panel_image = tk.Label(frame, image=img).pack()
    
def caption():
    
    original = Image.open(image_data)
    original = original.resize((224, 224), Image.ANTIALIAS)
    numpy_image = img_to_array(original)
    nimage = preprocess_input(numpy_image)
    
    feature = modelvgg.predict(nimage.reshape( (1,) + nimage.shape[:3]))
    caption = predict_caption(feature)
    table = tk.Label(frame, text="Caption: " + caption[9:-7], font=("Helvetica", 12)).pack()

# %%
import tkinter as tk
from tkinter import filedialog
from PIL import Image, ImageTk
import os

# Change the working directory to where your images are stored
os.chdir('C:\ss\image_caption\Flickr8k_text')

# Initialize Tkinter root window
root = tk.Tk()
root.title('IMAGE DESCRIPTION')

# Set window size and background
root.geometry('600x550')
root.resizable(False, False)
root.configure(bg='#D1EDf2')

# Create main frame for the UI
frame = tk.Frame(root, bg='white')
frame.place(relwidth=0.8, relheight=0.8, relx=0.1, rely=0.1)

# Function to upload image
def upload_img():
    global img, image_data
    for widget in frame.winfo_children():
        widget.destroy()

    image_data = filedialog.askopenfilename(initialdir="/", title="Choose an image",
                                       filetypes=(("all files", "*.*"), ("png files", "*.png")))
    if image_data:
        basewidth = 300
        img = Image.open(image_data)
        wpercent = (basewidth / float(img.size[0]))
        hsize = int((float(img.size[1]) * float(wpercent)))
        img = img.resize((basewidth, hsize), Image.LANCZOS)  # Use Image.LANCZOS for resizing
        img = ImageTk.PhotoImage(img)
        
        file_name = image_data.split('/')
        panel = tk.Label(frame, text=str(file_name[-1]).upper())
        panel.pack()

        panel_image = tk.Label(frame, image=img)
        panel_image.pack()

# Function to generate caption (placeholder)
def caption():
    global image_data
    if image_data:
        # Add your caption generation code here
        caption_text = "Group of people sitting in the mountain"  # Replace with actual caption logic
        caption_text = "A man in street racer armor be examine the tire of another racer 's motorbike"
        # Display caption in label
        caption_label.config(text="Caption: " + caption_text)
    else:
        print("No image selected.")

# Button to upload image
chose_image = tk.Button(root, text='Choose Image', padx=5, pady=10,
                        fg="black", bg="pink", command=upload_img, activebackground="#add8e6")
chose_image.pack(side=tk.LEFT)

# Button to generate caption
caption_image = tk.Button(root, text='Generate Caption', padx=35, pady=10,
                          fg="black", bg="pink", command=caption, activebackground="#add8e6")
caption_image.pack(side=tk.RIGHT)

# Label for displaying caption
caption_label = tk.Label(root, text="Caption will appear here", font=("Helvetica", 12))
caption_label.pack()

# Start Tkinter main loop
root.mainloop()
